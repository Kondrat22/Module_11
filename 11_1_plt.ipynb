# %%
import matplotlib.pyplot as plt
print("Пример библиотеки Matplotlib:")
# plt.style.use('seaborn-whitegrid')
fig, ax = plt.subplots()
x = [-3, -2, -1, 0, 1, 2, 3]
y = [9, 4, 1, 0, 1, 4, 9]
print(ax.plot(x, y))
# Out:
# Пример библиотеки Matplotlib:
# ...
